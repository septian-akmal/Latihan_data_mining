# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import tree

# %%
sayaDataset = pd.read_csv('Tugas_PT7.csv', 
                          delimiter=';', header=0)

# %%
sayaDataset.head()

# %%
saya = datasets.load_saya()
features = saya['data']
target = saya['target']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-02382b797130> in <module>()
# ----> 1 saya = datasets.load_saya()
#       2 features = saya['data']
#       3 target = saya['target']
#
# AttributeError: module 'sklearn.datasets' has no attribute 'load_saya'
